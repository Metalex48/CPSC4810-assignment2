# %% [markdown]
# # Assignment 2 - Analyzing Thanksgiving Dinner

# %% [markdown]
# In this assignment, you will work with the **Thanksgiving Dinner Dataset**. The dataset was created by FiveThirtyEight using a SurveyMonkey poll, in which they asked 1,058 respondents on Nov. 17, 2015 a number of questions regarding their Thanksgiving preferences.
#
# No details are needed for the attributes of this dataset as each column is a long self-explanatory string. You would have to read this dataset using a specific encoding scheme (Hint: Latin), otherwise it would result in read errors.

# %%
### Write your code below this comment.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/thanksgiving.csv", encoding = 'Latin')
df
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...                                                 ...
# 1053                                             Turkey
# 1054                                             Turkey
# 1055                             Other (please specify)
# 1056                                             Turkey
# 1057                                             Turkey
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1053                                                NaN
# 1054                                                NaN
# 1055                                               Duck
# 1056                                                NaN
# 1057                                                NaN
#
#      How is the main dish typically cooked?  \
# 0                                     Baked
# 1                                     Baked
# 2                                   Roasted
# 3                                     Baked
# 4                                     Baked
# ...                                     ...
# 1053                                Roasted
# 1054                                  Baked
# 1055                                  Baked
# 1056                                  Baked
# 1057                                  Baked
#
#      How is the main dish typically cooked? - Other (please specify)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      What kind of stuffing/dressing do you typically have?  \
# 0                                           Bread-based
# 1                                           Bread-based
# 2                                            Rice-based
# 3                                           Bread-based
# 4                                           Bread-based
# ...                                                 ...
# 1053                                        Bread-based
# 1054                                        Bread-based
# 1055                                         Rice-based
# 1056                                               None
# 1057                                        Bread-based
#
#      What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      What type of cranberry saucedo you typically have?  \
# 0                                                  None
# 1                                Other (please specify)
# 2                                              Homemade
# 3                                              Homemade
# 4                                                Canned
# ...                                                 ...
# 1053                                           Homemade
# 1054                                             Canned
# 1055                                               None
# 1056                                           Homemade
# 1057                                             Canned
#
#      What type of cranberry saucedo you typically have? - Other (please specify)  \
# 0                                                   NaN
# 1                       Homemade cranberry gelatin ring
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 1053  ...
# 1054  ...
# 1055  ...
# 1056  ...
# 1057  ...
#
#      Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 0                                                   Yes
# 1                                                    No
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 1053                                                Yes
# 1054                                                 No
# 1055                                                Yes
# 1056                                                Yes
# 1057                                                Yes
#
#      Have you ever attended a "Friendsgiving?"  \
# 0                                           No
# 1                                           No
# 2                                          Yes
# 3                                           No
# 4                                           No
# ...                                        ...
# 1053                                       Yes
# 1054                                        No
# 1055                                       Yes
# 1056                                        No
# 1057                                       Yes
#
#      Will you shop any Black Friday sales on Thanksgiving Day?  \
# 0                                                    No
# 1                                                   Yes
# 2                                                   Yes
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 1053                                                 No
# 1054                                                 No
# 1055                                                Yes
# 1056                                                Yes
# 1057                                                Yes
#
#      Do you work in retail? Will you employer make you work on Black Friday?  \
# 0                        No                                              NaN
# 1                        No                                              NaN
# 2                        No                                              NaN
# 3                        No                                              NaN
# 4                        No                                              NaN
# ...                     ...                                              ...
# 1053                     No                                              NaN
# 1054                     No                                              NaN
# 1055                     No                                              NaN
# 1056                    Yes                                              Yes
# 1057                     No                                              NaN
#
#      How would you describe where you live?      Age What is your gender?  \
# 0                                  Suburban  18 - 29                 Male
# 1                                     Rural  18 - 29               Female
# 2                                  Suburban  18 - 29                 Male
# 3                                     Urban  30 - 44                 Male
# 4                                     Urban  30 - 44                 Male
# ...                                     ...      ...                  ...
# 1053                                  Rural  30 - 44               Female
# 1054                               Suburban      60+               Female
# 1055                                  Urban      60+                 Male
# 1056                                    NaN      NaN                  NaN
# 1057                                    NaN      NaN                  NaN
#
#      How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                    $75,000 to $99,999
# 1                                    $50,000 to $74,999
# 2                                          $0 to $9,999
# 3                                       $200,000 and up
# 4                                  $100,000 to $124,999
# ...                                                 ...
# 1053                               $100,000 to $124,999
# 1054                                 $50,000 to $74,999
# 1055                               $100,000 to $124,999
# 1056                                                NaN
# 1057                                                NaN
#
#                US Region
# 0        Middle Atlantic
# 1     East South Central
# 2               Mountain
# 3                Pacific
# 4                Pacific
# ...                  ...
# 1053            Mountain
# 1054             Pacific
# 1055             Pacific
# 1056                 NaN
# 1057                 NaN
#
# [1058 rows x 65 columns]

# %% [markdown]
# ### Can you report the number of rows and columns in this dataset?

# %%
### Write your code below this comment.

# %%
df.shape
# Out:
# (1058, 65)

# %% [markdown]
# ### Can you access the column labeled `Do you celebrate Thanksgiving?` both as a Series and Dataframe?

# %%
### Write your code below this comment.

# %%
df['Do you celebrate Thanksgiving?']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 1053    Yes
# 1054    Yes
# 1055    Yes
# 1056    Yes
# 1057    Yes
# Name: Do you celebrate Thanksgiving?, Length: 1058, dtype: object

# %%
df[['Do you celebrate Thanksgiving?']]
# Out:
#      Do you celebrate Thanksgiving?
# 0                               Yes
# 1                               Yes
# 2                               Yes
# 3                               Yes
# 4                               Yes
# ...                             ...
# 1053                            Yes
# 1054                            Yes
# 1055                            Yes
# 1056                            Yes
# 1057                            Yes
#
# [1058 rows x 1 columns]

# %% [markdown]
# ### Can you report how many people responded 'Yes' and 'No' to the question 'Do you celebrate Thanksgiving?'

# %%
### Write your code below this comment.

# %%
df[['Do you celebrate Thanksgiving?']].value_counts()
# Out:
# Do you celebrate Thanksgiving?
# Yes                               980
# No                                 78
# dtype: int64

# %% [markdown]
# ### Can you plot a bar chart of the proportion (percentage) of people who responded 'Yes' and 'No' to the question 'Do you celebrate Thanksgiving?'
# <u>Note:</u> For this, you would need to neglect people who opted not to respond to this question.

# %%
### Write your code below this comment.

# %%
import matplotlib.pyplot as plt

# %%
df[['Do you celebrate Thanksgiving?']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Do you celebrate Thanksgiving?'>

# %% [markdown]
# ### Can you report the counts of each of the different responses to the question 'What is typically the main dish at your Thanksgiving dinner?'

# %%
### Write your code below this comment.

# %%
df[['What is typically the main dish at your Thanksgiving dinner?']].value_counts()
# Out:
# What is typically the main dish at your Thanksgiving dinner?
# Turkey                                                          859
# Other (please specify)                                           35
# Ham/Pork                                                         29
# Tofurkey                                                         20
# Chicken                                                          12
# Roast beef                                                       11
# I don't know                                                      5
# Turducken                                                         3
# dtype: int64

# %% [markdown]
# ### Can you plot a bar chart of the proportion (percentage) of each of the different responses to the question 'What is typically the main dish at your Thanksgiving dinner?'
# <u>Note:</u> For this as well, you would need to neglect people who opted not to respond to this question.

# %%
### Write your code below this comment.

# %%
df[['What is typically the main dish at your Thanksgiving dinner?']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='What is typically the main dish at your Thanksgiving dinner?'>

# %% [markdown]
# ### Can you get the list of all columns this dataset has?
# <u>Note:</u> This is because we can see that not all columns are visible from the displayed dataframe.

# %%
### Write your code below this comment.

# %%
column_list = list(df.columns)
print(column_list)
# Out:
# ['RespondentID', 'Do you celebrate Thanksgiving?', 'What is typically the main dish at your Thanksgiving dinner?', 'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)', 'How is the main dish typically cooked?', 'How is the main dish typically cooked? - Other (please specify)', 'What kind of stuffing/dressing do you typically have?', 'What kind of stuffing/dressing do you typically have? - Other (please specify)', 'What type of cranberry saucedo you typically have?', 'What type of cranberry saucedo you typically have? - Other (please specify)', 'Do you typically have gravy?', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cornbread', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Fruit salad', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Macaroni and cheese', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Rolls/biscuits', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Squash', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Vegetable salad', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Yams/sweet potato casserole', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Other (please specify)', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Other (please specify).1', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Buttermilk', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - None', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Other (please specify)', 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Other (please specify).1', 'Wh ...

# %% [markdown]
# ### Can you get the integer indices of the the following columns programmatically (i.e. without manually counting the index of the column)?
# <u>Note:</u> I want you to do this as I would like you to access these columns more succintly (using just their integer indices instead of labels) going forward into the assignment.

# %% [markdown]
# ```Do you typically have gravy?```
#
# ```Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple```
#
# ```Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan```
#
# ```Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin```
#
# ```How far will you travel for Thanksgiving?```
#
# ```Have you ever tried to meet up with hometown friends on Thanksgiving night?```
#
# ```Have you ever attended a "Friendsgiving?```
#
# ```How much total combined money did all members of your HOUSEHOLD earn last year?```

# %%
### Write your code below this comment.

# %%
q1 = 'Do you typically have gravy?'
q2 = 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'
q3 = 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'
q4 = 'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'
q5 = 'How far will you travel for Thanksgiving?'
q6 = 'Have you ever tried to meet up with hometown friends on Thanksgiving night?'
q7 = 'Have you ever attended a "Friendsgiving?"'
q8 = 'How much total combined money did all members of your HOUSEHOLD earn last year?'

q_list = [q1,q2,q3,q4,q5,q6,q7,q8]

# %%
def get_q_index(question):
    index_question = column_list.index(question)
    return index_question

# %%
for i in q_list:
    print(get_q_index(i))
# Out:
# 10
# 26
# 33
# 34
# 52
# 55
# 56
# 63

# %% [markdown]
# ### Can you report the total number of people who typically have gravy and the main dish at their Thanksgiving dinner was Tofurkey?

# %%
### Write your code below this comment.

# %%
q9 = 'What is typically the main dish at your Thanksgiving dinner?'
i_q9 = column_list.index(q9)
i_q9
# Out:
# 2

# %%
df[ (df.iloc[:,10]=='Yes') & (df.iloc[:,2]=='Tofurkey')]['RespondentID'].count()
# Out:
# 12

# %% [markdown]
# ### Can you report the total number of people who typically have all three types of pie served at their Thanksgiving dinner?

# %%
### Write your code below this comment.

# %%
# indices 26 33 34
df[(df.iloc[:,26]=='Apple') & (df.iloc[:,33]=='Pecan') & (df.iloc[:,34]=='Pumpkin')]
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 2       4337935621                            Yes
# 18      4337844879                            Yes
# 25      4337790002                            Yes
# 37      4337747968                            Yes
# 38      4337743121                            Yes
# ...            ...                            ...
# 1038    4335954131                            Yes
# 1041    4335951505                            Yes
# 1042    4335951437                            Yes
# 1046    4335949486                            Yes
# 1047    4335949169                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 2                                                Turkey
# 18                                               Turkey
# 25                                               Turkey
# 37                                               Turkey
# 38                                               Turkey
# ...                                                 ...
# 1038                                             Turkey
# 1041                                             Turkey
# 1042                                             Turkey
# 1046                                             Turkey
# 1047                                             Turkey
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 2                                                   NaN
# 18                                                  NaN
# 25                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# ...                                                 ...
# 1038                                                NaN
# 1041                                                NaN
# 1042                                                NaN
# 1046                                                NaN
# 1047                                                NaN
#
#      How is the main dish typically cooked?  \
# 2                                   Roasted
# 18                                    Baked
# 25                                  Roasted
# 37                             I don't know
# 38                                    Baked
# ...                                     ...
# 1038                                  Baked
# 1041                                Roasted
# 1042                                  Baked
# 1046                                  Baked
# 1047                                Roasted
#
#      How is the main dish typically cooked? - Other (please specify)  \
# 2                                                   NaN
# 18                                                  NaN
# 25                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# ...                                                 ...
# 1038                                                NaN
# 1041                                                NaN
# 1042                                                NaN
# 1046                                                NaN
# 1047                                                NaN
#
#      What kind of stuffing/dressing do you typically have?  \
# 2                                            Rice-based
# 18                                          Bread-based
# 25                                          Bread-based
# 37                                          Bread-based
# 38                                          Bread-based
# ...                                                 ...
# 1038                                        Bread-based
# 1041                             Other (please specify)
# 1042                                        Bread-based
# 1046                                        Bread-based
# 1047                                        Bread-based
#
#      What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 2                                                   NaN
# 18                                                  NaN
# 25                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# ...                                                 ...
# 1038                                                NaN
# 1041                                          Cornbread
# 1042                                                NaN
# 1046                                                NaN
# 1047                                                NaN
#
#      What type of cranberry saucedo you typically have?  \
# 2                                              Homemade
# 18                                               Canned
# 25                                             Homemade
# 37                                             Homemade
# 38                                               Canned
# ...                                                 ...
# 1038                                             Canned
# 1041                                             Canned
# 1042                                             Canned
# 1046                                             Canned
# 1047                                             Canned
#
#      What type of cranberry saucedo you typically have? - Other (please specify)  \
# 2                                                   NaN
# 18                                                  NaN
# 25                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# ...                                                 ...
# 1038                                                NaN
# 1041                                                NaN
# 1042                                                NaN
# 1046                                                NaN
# 1047                                                NaN
#
#       ...  \
# 2     ...
# 18    ...
# 25    ...
# 37    ...
# 38    ...
# ...   ...
# 1038  ...
# 1041  ...
# 1042  ...
# 1046  ...
# 1047  ...
#
#      Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 2                                                   Yes
# 18                                                   No
# 25                                                   No
# 37                                                   No
# 38                                                  Yes
# ...                                                 ...
# 1038                                                 No
# 1041                                                 No
# 1042                                                 No
# 1046                                                Yes
# 1047                                                 No
#
#      Have you ever attended a "Friendsgiving?"  \
# 2                                          Yes
# 18                                          No
# 25                                          No
# 37                                          No
# 38                                          No
# ...                                        ...
# 1038                                        No
# 1041                                        No
# 1042                                        No
# 1046                                       Yes
# 1047                                       Yes
#
#      Will you shop any Black Friday sales on Thanksgiving Day?  \
# 2                                                   Yes
# 18                                                   No
# 25                                                   No
# 37                                                   No
# 38                                                   No
# ...                                                 ...
# 1038                                                 No
# 1041                                                Yes
# 1042                                                 No
# 1046                                                Yes
# 1047                                                 No
#
#      Do you work in retail? Will you employer make you work on Black Friday?  \
# 2                        No                                              NaN
# 18                       No                                              NaN
# 25                       No                                              NaN
# 37                      Yes                                              Yes
# 38                       No                                              NaN
# ...                     ...                                              ...
# 1038                     No                                              NaN
# 1041                     No                                              NaN
# 1042                     No                                              NaN
# 1046                    Yes                                               No
# 1047                     No                                              NaN
#
#      How would you describe where you live?      Age What is your gender?  \
# 2                                  Suburban  18 - 29                 Male
# 18                                 Suburban  30 - 44                 Male
# 25                                    Rural  18 - 29                 Male
# 37                                 Suburban  18 - 29                 Male
# 38                                 Suburban  18 - 29                 Male
# ...                                     ...      ...                  ...
# 1038                               Suburban      60+                 Male
# 1041                                  Rural  45 - 59               Female
# 1042                                  Rural  45 - 59               Female
# 1046                                  Urban  18 - 29                 Male
# 1047                                  Urban  30 - 44               Female
#
#      How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 2                                          $0 to $9,999
# 18                                   $25,000 to $49,999
# 25                                      $200,000 and up
# 37                                 Prefer not to answer
# 38                                   $25,000 to $49,999
# ...                                                 ...
# 1038                               $100,000 to $124,999
# 1041                                 $25,000 to $49,999
# 1042                               $125,000 to $149,999
# 1046                                 $10,000 to $24,999
# 1047                                 $25,000 to $49,999
#
#                US Region
# 2               Mountain
# 18              Mountain
# 25       Middle Atlantic
# 37           New England
# 38               Pacific
# ...                  ...
# 1038             Pacific
# 1041  West South Central
# 1042            Mountain
# 1046      South Atlantic
# 1047             Pacific
#
# [137 rows x 65 columns]

# %% [markdown]
# ### Can you report the total number of people who didn't check any of the options (Apple, Pecan, or Pumpkin) in response to the question "Which type of pie is typically served at your Thanksgiving dinner"?

# %%
### Write your code below this comment.

# %%
df[(df.iloc[:,26]!='Apple') & (df.iloc[:,33]!='Pecan') & (df.iloc[:,34]!='Pumpkin')]
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 5       4337929779                            Yes
# 7       4337916002                            Yes
# 10      4337899680                             No
# 15      4337857295                            Yes
# 21      4337813502                            Yes
# ...            ...                            ...
# 1037    4335954207                            Yes
# 1043    4335951082                            Yes
# 1052    4335944115                             No
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 5                                                Turkey
# 7                                                Turkey
# 10                                                  NaN
# 15                                               Turkey
# 21                                               Turkey
# ...                                                 ...
# 1037                             Other (please specify)
# 1043                                             Turkey
# 1052                                                NaN
# 1056                                             Turkey
# 1057                                             Turkey
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 5                                                   NaN
# 7                                                   NaN
# 10                                                  NaN
# 15                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 1037                                             salmon
# 1043                                                NaN
# 1052                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      How is the main dish typically cooked?  \
# 5                                   Roasted
# 7                                     Baked
# 10                                      NaN
# 15                                  Roasted
# 21                                    Fried
# ...                                     ...
# 1037                                  Baked
# 1043                                Roasted
# 1052                                    NaN
# 1056                                  Baked
# 1057                                  Baked
#
#      How is the main dish typically cooked? - Other (please specify)  \
# 5                                                   NaN
# 7                                                   NaN
# 10                                                  NaN
# 15                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 1037                                                NaN
# 1043                                                NaN
# 1052                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      What kind of stuffing/dressing do you typically have?  \
# 5                                            Rice-based
# 7                                            Rice-based
# 10                                                  NaN
# 15                                           Rice-based
# 21                                                 None
# ...                                                 ...
# 1037                                               None
# 1043                                        Bread-based
# 1052                                                NaN
# 1056                                               None
# 1057                                        Bread-based
#
#      What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 5                                                   NaN
# 7                                                   NaN
# 10                                                  NaN
# 15                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 1037                                                NaN
# 1043                                                NaN
# 1052                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#      What type of cranberry saucedo you typically have?  \
# 5                                              Homemade
# 7                                              Homemade
# 10                                                  NaN
# 15                                               Canned
# 21                                             Homemade
# ...                                                 ...
# 1037                                               None
# 1043                                               None
# 1052                                                NaN
# 1056                                           Homemade
# 1057                                             Canned
#
#      What type of cranberry saucedo you typically have? - Other (please specify)  \
# 5                                                   NaN
# 7                                                   NaN
# 10                                                  NaN
# 15                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 1037                                                NaN
# 1043                                                NaN
# 1052                                                NaN
# 1056                                                NaN
# 1057                                                NaN
#
#       ...  \
# 5     ...
# 7     ...
# 10    ...
# 15    ...
# 21    ...
# ...   ...
# 1037  ...
# 1043  ...
# 1052  ...
# 1056  ...
# 1057  ...
#
#      Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 5                                                   Yes
# 7                                                   Yes
# 10                                                  NaN
# 15                                                  Yes
# 21                                                  Yes
# ...                                                 ...
# 1037                                                 No
# 1043                                                 No
# 1052                                                NaN
# 1056                                                Yes
# 1057                                                Yes
#
#      Have you ever attended a "Friendsgiving?"  \
# 5                                          Yes
# 7                                          Yes
# 10                                         NaN
# 15                                         Yes
# 21                                         Yes
# ...                                        ...
# 1037                                        No
# 1043                                        No
# 1052                                       NaN
# 1056                                        No
# 1057                                       Yes
#
#      Will you shop any Black Friday sales on Thanksgiving Day?  \
# 5                                                   Yes
# 7                                                   Yes
# 10                                                  NaN
# 15                                                   No
# 21                                                  Yes
# ...                                                 ...
# 1037                                                 No
# 1043                                                 No
# 1052                                                NaN
# 1056                                                Yes
# 1057                                                Yes
#
#      Do you work in retail? Will you employer make you work on Black Friday?  \
# 5                        No                                              NaN
# 7                       Yes                                              Yes
# 10                      NaN                                              NaN
# 15                       No                                              NaN
# 21                      Yes                                              Yes
# ...                     ...                                              ...
# 1037                     No                                              NaN
# 1043                     No                                              NaN
# 1052                    NaN                                              NaN
# 1056                    Yes                                              Yes
# 1057                     No                                              NaN
#
#      How would you describe where you live?      Age What is your gender?  \
# 5                                     Urban  18 - 29                 Male
# 7                                     Rural  18 - 29                 Male
# 10                                      NaN  30 - 44                 Male
# 15                                 Suburban  30 - 44                 Male
# 21                                    Urban  18 - 29                 Male
# ...                                     ...      ...                  ...
# 1037                               Suburban  30 - 44               Female
# 1043                               Suburban  45 - 59                 Male
# 1052                                    NaN  18 - 29                 Male
# 1056                                    NaN      NaN                  NaN
# 1057                                    NaN      NaN                  NaN
#
#      How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 5                                          $0 to $9,999
# 7                                  Prefer not to answer
# 10                                   $25,000 to $49,999
# 15                                      $200,000 and up
# 21                                         $0 to $9,999
# ...                                                 ...
# 1037                                 $10,000 to $24,999
# 1043                                 $75,000 to $99,999
# 1052                                       $0 to $9,999
# 1056                                                NaN
# 1057                                                NaN
#
#                US Region
# 5                Pacific
# 7               Mountain
# 10              Mountain
# 15               Pacific
# 21               Pacific
# ...                  ...
# 1037             Pacific
# 1043  East North Central
# 1052                 NaN
# 1056                 NaN
# 1057                 NaN
#
# [182 rows x 65 columns]

# %% [markdown]
# ### Can you report the number of people in each of the four different age groups?

# %%
### Write your code below this comment.

# %%
qx = 'Age'
get_q_index(qx)
# Out:
# 61

# %%
df.iloc[:,61].value_counts()
# Out:
# 45 - 59    286
# 60+        264
# 30 - 44    259
# 18 - 29    216
# Name: Age, dtype: int64

# %% [markdown]
# ### Can you write a small function to extract the numerical age for each person from the categorical variable "Age"? Create a new column "int_age" that contains the numerical data.
# <u>Note:</u> To keep things simple, assume that the numerical age of each person is the lower bound of the age group. For example, the numerical age for a person in the group 45 - 59 would be 45. However, for the last 60+ group, the age would be 60.

# %%
### Write your code below this comment.

# %%
def new_col_int (a,x,y):
    df[a] = df.iloc[:,x].str[:y].astype(float)

# %%
new_col_int('int_age',61,2)

# %% [markdown]
# ### Can you report the most frequent income bracket in response to the question "How much total combined money did all members of your HOUSEHOLD earn last year"?

# %%
### Write your code below this comment.

# %%
df.iloc[:,63].value_counts()
# Out:
# $25,000 to $49,999      180
# Prefer not to answer    136
# $50,000 to $74,999      135
# $75,000 to $99,999      133
# $100,000 to $124,999    111
# $200,000 and up          80
# $10,000 to $24,999       68
# $0 to $9,999             66
# $125,000 to $149,999     49
# $150,000 to $174,999     40
# $175,000 to $199,999     27
# Name: How much total combined money did all members of your HOUSEHOLD earn last year?, dtype: int64

# %% [markdown]
# ### Can you write a small function to extract the numerical income for each person from the categorical variable "How much total combined money did all members of your HOUSEHOLD earn last year"? Create a new column "int_income" that contains the numerical data.
# <u>Note:</u> To keep things simple, assume that the numerical income of each person is the lower bound of the income group. For example, the numerical income for a person in the group "75,000 to 99,999" would be 75000.

# %%
### Write your code below this comment.

# %%
df['int_income'] = df.iloc[:,63].str.split().str.get(0) # splitting the string to get the first word only.
df['int_income'] = df['int_income'].replace(['Prefer','[$,]'],
                                            [np.nan,''],regex=True).astype(float) 
                                            #getting rid of the '$' and ',' symbols

# %% [markdown]
# ### Now display the first five rows of your dataset.

# %%
### Write your code below this comment.

# %%
df.head(5)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
# 2                                Roasted
# 3                                  Baked
# 4                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# 1                                        Bread-based
# 2                                         Rice-based
# 3                                        Bread-based
# 4                                        Bread-based
#
#   What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What type of cranberry saucedo you typically have?  \
# 0                                               None
# 1                             Other (please specify)
# 2                                           Homemade
# 3                                           Homemade
# 4                                             Canned
#
#   What type of cranberry saucedo you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                    Homemade cranberry gelatin ring
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ... Will you shop any Black Friday sales on Thanksgiving Day?  \
# 0  ...                                                 No
# 1  ...                                                Yes
# 2  ...                                                Yes
# 3  ...                                                 No
# 4  ...                                                 No
#
#   Do you work in retail? Will you employer make you work on Black Friday?  \
# 0                     No                                              NaN
# 1                     No                                              NaN
# 2                     No                                              NaN
# 3                     No                                              NaN
# 4                     No                                              NaN
#
#   How would you describe where you live?      Age What is your gender?  \
# 0                               Suburban  18 - 29                 Male
# 1                                  Rural  18 - 29               Female
# 2                               Suburban  18 - 29                 Male
# 3                                  Urban  30 - 44                 Male
# 4                                  Urban  30 - 44                 Male
#
#   How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                 $75,000 to $99,999
# 1                                 $50,000 to $74,999
# 2                                       $0 to $9,999
# 3                                    $200,000 and up
# 4                               $100,000 to $124,999
#
#             US Region int_age int_income
# 0     Middle Atlantic    18.0    75000.0
# 1  East South Central    18.0    50000.0
# 2            Mountain    18.0        0.0
# 3             Pacific    30.0   200000.0
# 4             Pacific    30.0   100000.0
#
# [5 rows x 67 columns]

# %% [markdown]
# ### Using the newly created numerical income column, can you generate some descriptive statistics (such as mean, standard deviation, minimum, maximum etc) about this column?
# <u>Note:</u> Use a single method that gives you all the statistics.

# %%
### Write your code below this comment.

# %%
df.iloc[:,-1:].describe()
# Out:
#           int_income
# count     889.000000
# mean    74077.615298
# std     59360.742902
# min         0.000000
# 25%     25000.000000
# 50%     50000.000000
# 75%    100000.000000
# max    200000.000000

# %% [markdown]
# ### Can you figure out how far people with an income less than 15000 travel for Thanksgiving?

# %%
### Write your code below this comment.

# %%
df.iloc[:,52].value_counts()  # values of original DF
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         396
# Thanksgiving is local--it will take place in the town I live in                     276
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    197
# Thanksgiving is out of town and far away--I have to drive several hours or fly       82
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %%
df[df['int_income']<15000].iloc[:,52].value_counts() # values of people with income less than $15,000
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         46
# Thanksgiving is local--it will take place in the town I live in                     38
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    22
# Thanksgiving is out of town and far away--I have to drive several hours or fly       6
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# ### Also, can you figure out how far people with an income greater than 15000 travel for Thanksgiving?

# %%
### Write your code below this comment.

# %%
df[df['int_income']>15000].iloc[:,52].value_counts()
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         301
# Thanksgiving is local--it will take place in the town I live in                     199
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    153
# Thanksgiving is out of town and far away--I have to drive several hours or fly       64
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# ### Can you figure out the mean age of those who ever attended a "Friendsgiving" and also tried to meet up with hometown friends on Thanksgiving night?

# %%
### Write your code below this comment.

# %%
df.iloc[:,55].value_counts()
# Out:
# No     594
# Yes    357
# Name: Have you ever tried to meet up with hometown friends on Thanksgiving night?, dtype: int64

# %%
df.iloc[:,56].value_counts()
# Out:
# No     683
# Yes    268
# Name: Have you ever attended a "Friendsgiving?", dtype: int64

# %%
df[(df.iloc[:,55]=='Yes') & (df.iloc[:,56]=='Yes')]['int_age'].mean()
# Out:
# 33.97674418604651

# %% [markdown]
# ### Can you save the resulting dataframe (which includes the numerical age and income columns) as a CSV file?

# %%
### Write your code below this comment.

# %%
df.to_csv("Data/thanksgiving2.csv")
